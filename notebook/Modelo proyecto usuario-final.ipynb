# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import tkinter as tk
from tkinter import simpledialog, messagebox, ttk
import threading

# %%
dfre = pd.read_csv('cartelera.csv')

# %%
gui_finished_event = threading.Event()

def obtener_valoraciones():
    valoraciones = {}
    while True:
        # Crear una ventana de diálogo personalizada con autocompletar
        dialog = AutocompleteDialog(root, dfre['title'].values)
        root.wait_window(dialog.top)
        
        title = dialog.result
        if not title:
            break
        # Verificar si el título está en la cartelera
        if title not in dfre['title'].values:
            messagebox.showerror("Error", f"La película '{title}' no está en nuestra cartelera.")
            continue
        # Preguntar al usuario por la valoración de la película
        rating = simpledialog.askfloat("Input", f"Introduce la valoración para '{title}':")
        if rating is not None:
            valoraciones[title] = rating
    return valoraciones

def mostrar_resultado(df):
    if df.empty:
        messagebox.showinfo("Información", "No hay datos de películas valoradas para mostrar.")
    else:
        result_window = tk.Toplevel(root)
        result_window.title("Películas Valoradas")
        text = tk.Text(result_window)
        text.pack(expand=True, fill='both')
        text.insert(tk.END, df.to_string(index=False))

def main():
    global df_valoraciones_completas
    valoraciones = obtener_valoraciones()
    print("Valoraciones obtenidas:", valoraciones)  # Mensaje de diagnóstico
    if valoraciones:
        # Convertir las valoraciones a un DataFrame
        df_nuevas_valoraciones = pd.DataFrame(list(valoraciones.items()), columns=['title', 'Rating'])
        print("DataFrame de nuevas valoraciones creado:\n", df_nuevas_valoraciones)  # Mensaje de diagnóstico
        # Unir con dfre para obtener todos los datos de las películas valoradas
        df_valoraciones_completas = pd.merge(left=df_nuevas_valoraciones, right=dfre, left_on='title', right_on='title', how='inner')
        print("DataFrame de valoraciones completas creado:\n", df_valoraciones_completas)  # Mensaje de diagnóstico
        mostrar_resultado(df_valoraciones_completas)
    else:
        messagebox.showinfo("Información", "No se introdujeron valoraciones.")
    # Señalar que la GUI ha terminado
    gui_finished_event.set()

def run_gui():
    global root
    root = tk.Tk()
    root.withdraw()  # Esconder la ventana principal
    main()
    root.mainloop()

class AutocompleteDialog:
    def __init__(self, parent, suggestions):
        top = self.top = tk.Toplevel(parent)
        self.top.title("Introduce el título de la película")
        self.suggestions = suggestions
        self.result = None
        
        self.label = tk.Label(top, text="Introduce el título de la película (o deja vacío para terminar):")
        self.label.pack(side="top", fill="x", padx=20, pady=5)
        
        self.entry_var = tk.StringVar()
        self.entry = ttk.Entry(top, textvariable=self.entry_var)
        self.entry.pack(side="top", fill="x", padx=20, pady=5)
        
        self.listbox = tk.Listbox(top)
        self.listbox.pack(side="top", fill="both", expand=True, padx=20, pady=5)
        
        self.entry_var.trace("w", self.update_listbox)
        self.entry.bind("<Return>", self.on_select)
        self.listbox.bind("<Double-Button-1>", self.on_select)
        
        self.entry.focus_set()

    def update_listbox(self, *args):
        search_term = self.entry_var.get()
        self.listbox.delete(0, tk.END)
        for item in self.suggestions:
            if search_term.lower() in item.lower():
                self.listbox.insert(tk.END, item)
    
    def on_select(self, event=None):
        try:
            index = self.listbox.curselection()[0]
            self.result = self.listbox.get(index)
        except IndexError:
            self.result = self.entry_var.get()
        self.top.destroy()

# Ejecutar la interfaz gráfica en un hilo separado
thread = threading.Thread(target=run_gui)
thread.start()

# Esperar hasta que la GUI termine
gui_finished_event.wait()

# Aquí puedes continuar con otras celdas del notebook
print("La interfaz gráfica ha terminado. Continuando con las siguientes celdas del notebook.")

# Mostrar el DataFrame de valoraciones completas para asegurarnos de que está disponible
if 'df_valoraciones_completas' in globals():
    print(df_valoraciones_completas.head())
else:
    print("No hay valoraciones completas disponibles.")
# Out:
# Valoraciones obtenidas: {'The Matrix': 3.0, 'The Lord of the Rings: The Two Towers': 5.0, 'The Lord of the Rings: The Fellowship of the Ring': 4.0, 'Star Wars': 2.0, 'Home Alone': 2.0, 'Thor: Ragnarok': 1.0, 'Game of Thrones': 4.0, 'Vikings': 4.0, 'Boarding School': 3.0}
# DataFrame de nuevas valoraciones creado:
#                                                 title  Rating
# 0                                         The Matrix     3.0
# 1              The Lord of the Rings: The Two Towers     5.0
# 2  The Lord of the Rings: The Fellowship of the Ring     4.0
# 3                                          Star Wars     2.0
# 4                                         Home Alone     2.0
# 5                                     Thor: Ragnarok     1.0
# 6                                    Game of Thrones     4.0
# 7                                            Vikings     4.0
# 8                                    Boarding School     3.0
# DataFrame de valoraciones completas creado:
#                                                 title  Rating        id   type  \
# 0                                         The Matrix     3.0      tm10  MOVIE
# 1              The Lord of the Rings: The Two Towers     5.0  tm115982  MOVIE
# 2  The Lord of the Rings: The Fellowship of the Ring     4.0   tm44313  MOVIE
# 3                                          Star Wars     2.0       tm1  MOVIE
# 4                                         Home Alone     2.0  tm155184  MOVIE
# 5                                     Thor: Ragnarok     1.0   tm12119  MOVIE
# 6                                    Game of Thrones     4.0       ts2   SHOW
# 7                                            Vikings     4.0   ts22413   SHOW
# 8                                    Boarding School     3.0  tm420343  MOVIE
#
#                                          description  release_year  \
# 0  Set in the 22nd century, The Matrix tells the ...          1999
# 1  Frodo and Sam are trekking to Mordor to destro...          2002
# 2  Young hobbit Frodo Baggins, after inheriting a...          2001
# 3  Princess Leia is captured and held hostage by ...          1977
# 4  Eight-year-old Kevin McCallister makes the mos...          1990
# 5  Thor is imprisoned on the other side of the un...          2017
# 6  Seven noble families fight for control of the ...          2011
# 7  The adventures of Ragnar Lothbrok, the greates...          2013
# 8  When troubled 12-year-old Jacob Felsen is sent...          2018
#
#   age_certification  runtime  \
# 0                 R      136
# 1             PG-13      179
# 2             PG-13      178
# 3                PG      121
# 4                PG      102
# 5             PG-13      131
# 6             TV-MA       58
# 7             TV-MA       45
# 8                 R      111
#
#                                               genres production_countries  \
# 0                                ['action', 'scifi']               ['US']
# 1                     ['action', 'fantasy', 'drama']         ['NZ', 'US']
# 2                     ['fantasy', 'action', 'drama']         ['NZ', 'US']
# 3                     ['action', 'scifi', 'fantasy']               ['US']
# 4                               ['comedy', 'family']               ['US']
# 5           ['scifi', 'action', 'fantasy', 'comedy']               ['US']
# 6  ['scifi', 'drama', 'action', 'romance', 'fanta...               ['US']
# 7  ['war', 'action', 'drama', 'history', 'romance...               ['CA']
# 8  ['horror', 'documentation', 'thriller', 'europ...               ['US']
#
#    ...    imdb_id imdb_score  imdb_votes  tmdb_popularity  tmdb_score  \
# 0  ...  tt0133093        8.7   1934137.0           76.460       8.200
# 1  ...  tt0167261        8.8   1684864.0           87.778       8.375
# 2  ...  tt0120737        8.8   1895545.0          110.122       8.394
# 3  ...  tt0076759        8.6   1378285.0           81.289       8.207
# 4  ...  tt0099785        7.7    599166.0            2.287       7.403
# 5  ...  tt3501632        7.9    764948.0          110.654       7.601
# 6  ...  tt0944947        9.2   2134702.0          559.489       8.400
# 7  ...  tt2306299        8.5    544091.0          419.921       8.077
# 8  ...  tt6224502        5.8      3755.0            9.715       6.400
#
#                                               actors  \
# 0  Keanu Reeves, Laurence Fishburne, Carrie-Anne ...
# 1  Viggo Mortensen, Elijah Wood, Sean Astin, Andy...
# 2  Elijah Wood, Ian McKellen, Viggo Mortensen, Se...
# 3  Mark Hamill, Harrison Ford, Carrie Fisher, Pet...
# 4  Macaulay Culkin, Joe Pesci, Daniel Stern, Cath...
# 5  Chris Hemsworth, Tom Hiddleston, Cate Blanchet...
# 6  Emilia Clarke, Peter Dinklage, Kit Harington, ...
# 7  Alex Høgh Andersen, Jordan Patrick Smith, Marc...
# 8  Luke Prael, Sterling Jerins, Nadia Alexander, ...
#
#                                            actor_ids  \
# 0  3036, 5834, 8128, 2858, 8129, 87121, 26158, 10...
# 1  2846, 2845, 2857, 1858, 3261, 2848, 2853, 2804...
# 2  2845, 2804, 2846, 2857, 2323, 2855, 2856, 2853...
# 3  1989, 1225, 1990, 1991, 1992, 1993, 1999, 2000...
# 4  21900, 9438, 32214, 11465, 1005, 12079, 17062,...
# 5  1736, 2134, 2859, 3161, 4614, 1675, 3263, 1844...
# 6  1800, 2319, 7112, 5807, 32340, 32339, 19638, 1...
# 7          42389, 21253, 41016, 38838, 21869, 917559
# 8  805286, 39366, 44348, 17670, 36886, 11242, 103...
#
#                          directors director_ids      platform
# 0  Lana Wachowski, Lilly Wachowski   5216, 5215           HBO
# 1                    Peter Jackson         1283  HBO, Netflix
# 2                    Peter Jackson         1283  HBO, Netflix
# 3                     George Lucas         2115        Disney
# 4                   Chris Columbus         2354        Disney
# 5                    Taika Waititi        20352        Disney
# 6                              NaN          NaN           HBO
# 7                              NaN          NaN        Amazon
# 8                       Boaz Yakin         7904        Amazon
#
# [9 rows x 21 columns]
# La interfaz gráfica ha terminado. Continuando con las siguientes celdas del notebook.
#                                                title  Rating        id   type  \
# 0                                         The Matrix     3.0      tm10  MOVIE
# 1              The Lord of the Rings: The Two Towers     5.0  tm115982  MOVIE
# 2  The Lord of the Rings: The Fellowship of the Ring     4.0   tm44313  MOVIE
# 3                                          Star Wars     2.0       tm1  MOVIE
# 4                                         Home Alone     2.0  tm155184  MOVIE
#
#                                          description  release_year  \
# 0  Set in the 22nd century, The Matrix tells the ...          1999
# 1  Frodo and Sam are trekking to Mordor to destro...          2002
# 2  Young hobbit Frodo Baggins, after inheriting a...          2001
# 3  Princess Leia is captured and held hostage by ...          1977
# 4  Eight-year-old Kevin McCallister makes the mos...          1990
#
#   age_certification  runtime                          genres  \
# 0                 R      136             ['action', 'scifi']
# 1             PG-13      179  ['action', 'fantasy', 'drama']
# 2             PG-13      178  ['fantasy', 'action', 'drama']
# 3                PG      121  ['action', 'scifi', 'fantasy']
# 4                PG      102            ['comedy', 'family']
#
#   production_countries  ...    imdb_id imdb_score  imdb_votes  \
# 0               ['US']  ...  tt0133093        8.7   1934137.0
# 1         ['NZ', 'US']  ...  tt0167261        8.8   1684864.0
# 2         ['NZ', 'US']  ...  tt0120737        8.8   1895545.0
# 3               ['US']  ...  tt0076759        8.6   1378285.0
# 4               ['US']  ...  tt0099785        7.7    599166.0
#
#    tmdb_popularity  tmdb_score  \
# 0           76.460       8.200
# 1           87.778       8.375
# 2          110.122       8.394
# 3           81.289       8.207
# 4            2.287       7.403
#
#                                               actors  \
# 0  Keanu Reeves, Laurence Fishburne, Carrie-Anne ...
# 1  Viggo Mortensen, Elijah Wood, Sean Astin, Andy...
# 2  Elijah Wood, Ian McKellen, Viggo Mortensen, Se...
# 3  Mark Hamill, Harrison Ford, Carrie Fisher, Pet...
# 4  Macaulay Culkin, Joe Pesci, Daniel Stern, Cath...
#
#                                            actor_ids  \
# 0  3036, 5834, 8128, 2858, 8129, 87121, 26158, 10...
# 1  2846, 2845, 2857, 1858, 3261, 2848, 2853, 2804...
# 2  2845, 2804, 2846, 2857, 2323, 2855, 2856, 2853...
# 3  1989, 1225, 1990, 1991, 1992, 1993, 1999, 2000...
# 4  21900, 9438, 32214, 11465, 1005, 12079, 17062,...
#
#                          directors director_ids      platform
# 0  Lana Wachowski, Lilly Wachowski   5216, 5215           HBO
# 1                    Peter Jackson         1283  HBO, Netflix
# 2                    Peter Jackson         1283  HBO, Netflix
# 3                     George Lucas         2115        Disney
# 4                   Chris Columbus         2354        Disney
#
# [5 rows x 21 columns]

# %%
dfme = df_valoraciones_completas

# %%
#generacion de los pesos por genero de cada usuario#
categorias_unicas = set()
for genero in dfre['genres'].dropna().values:
    # Limpiar las categorías eliminando corchetes, comillas y espacios innecesarios
    generos = genero.strip("[]").replace("'", "").replace('"', "").split(", ")
    generos = [g.strip().lower() for g in generos]
    categorias_unicas.update(generos)

categorias_unicas = list(categorias_unicas)

# Crear la matriz de datos para las categorías
datos = []

for row in dfme[dfme["Rating"] > 0]['genres'].dropna().values:
    categorias_peliculas = []
    row_generos = row.strip("[]").replace("'", "").replace('"', "").split(", ")
    row_generos = [g.strip().lower() for g in row_generos]
    for cat in categorias_unicas:
        categorias_peliculas.append(int(cat in row_generos))
    datos.append(categorias_peliculas)

#categorias_peliculas.append(int(cat in row.split(", ")))

df_generos_peliculas = pd.DataFrame(data = datos, columns = list(categorias_unicas))
dfme.reset_index(drop=True, inplace=True)

weighted_genre_matrix = pd.concat([dfme, df_generos_peliculas], axis = 1)
weighted_genre_matrix = (weighted_genre_matrix[categorias_unicas].values.T * weighted_genre_matrix['Rating'].values).T
weighted_genre_matrix = pd.DataFrame(weighted_genre_matrix, columns = categorias_unicas)

usuario_pesos = weighted_genre_matrix.sum()

usuario_pesos = usuario_pesos / usuario_pesos.sum()

for genero in categorias_unicas:
    if genero not in usuario_pesos:
        usuario_pesos[genero] = 0.0000


usuario_pesos
# Out:
#                  0.000000
# romance          0.077670
# animation        0.000000
# documentation    0.029126
# fantasy          0.155340
# comedy           0.029126
# horror           0.029126
# war              0.038835
# music            0.000000
# action           0.223301
# history          0.038835
# western          0.000000
# reality          0.000000
# sport            0.000000
# european         0.067961
# drama            0.165049
# crime            0.000000
# thriller         0.029126
# family           0.019417
# scifi            0.097087
# dtype: float64

# %%
# Definir un umbral de penalización o un factor de penalización
factor_penalizacion = 0.85
umbral_penalizacion = usuario_pesos.sort_values(ascending=False).iloc[2] 

usuario_pesos_penalizados = usuario_pesos.apply(lambda x: (x - umbral_penalizacion) * factor_penalizacion if x < umbral_penalizacion else x)
umbral_penalizacion
# Out:
# 0.1553398058252427

# %%
usuario_pesos_penalizados
# Out:
#                 -0.132039
# romance         -0.066019
# animation       -0.132039
# documentation   -0.107282
# fantasy          0.155340
# comedy          -0.107282
# horror          -0.107282
# war             -0.099029
# music           -0.132039
# action           0.223301
# history         -0.099029
# western         -0.132039
# reality         -0.132039
# sport           -0.132039
# european        -0.074272
# drama            0.165049
# crime           -0.132039
# thriller        -0.107282
# family          -0.115534
# scifi           -0.049515
# dtype: float64

# %%
#creo dataframe columnas por cada genero (en los pesos del usuario) y genero puntuacion por genero
datos = []
for row in dfre['genres'].dropna().values:
    categorias_peliculas = []
    row_generos = row.strip("[]").replace("'", "").replace('"', "").split(", ")
    row_generos = [g.strip().lower() for g in row_generos]
    for cat in categorias_unicas:
        categorias_peliculas.append(int(cat in row_generos))
    datos.append(categorias_peliculas)


df_generos_peliculas = pd.DataFrame(data=datos, columns=list(categorias_unicas))
dfre2 = pd.concat([dfre, df_generos_peliculas], axis=1)
dfre['Puntuacionge'] = (dfre2[categorias_unicas] * usuario_pesos_penalizados).sum(axis=1)

# %%
#esto es el codigo que me dijo dmitry lo dejo aqui comentado para luego intentar sustituirlo
#categorias_peliculas.append(int(cat in row.split(", ")))

# %%
#generacion de pesos del usuario por director
dfm2=dfme.dropna(subset = ['director_ids'])
dfm2.reset_index(drop=True, inplace=True)
directores = dfm2['director_ids'].unique().tolist()

datos_directores = []

for row in dfm2[dfm2["Rating"] > 0]["director_ids"].values:
    
    c_directores = []
    
    for director in directores :
    

        if director == row:
            c_directores.append(1)  
        else:
            c_directores.append(0)  
    

    datos_directores.append(c_directores)


df_directores = pd.DataFrame(data = datos_directores, columns = list(directores))

weighted_genre_matrix2 = pd.concat([dfm2, df_directores], axis = 1)
weighted_genre_matrix2 = (weighted_genre_matrix2[directores].values.T * weighted_genre_matrix2['Rating'].values).T
weighted_genre_matrix2 = pd.DataFrame(weighted_genre_matrix2, columns = directores )
usuario_d = weighted_genre_matrix2.sum()

usuario_d = usuario_d / usuario_d.sum()

usuario_d
# Out:
# 5216, 5215    0.15
# 1283          0.45
# 2115          0.10
# 2354          0.10
# 20352         0.05
# 7904          0.15
# dtype: float64

# %%
factor_penalizacion2 = 1.2
umbral_penalizacion2 = usuario_d.sort_values(ascending=False).iloc[1] 
usuario_dp = usuario_d.apply(lambda x:x * factor_penalizacion2 if x >= umbral_penalizacion2 else x)

# %%
# generar dataframe columnas por cada director (en los pesos del usuario) y generar puntuacion por director
datos_directores = []

for row in dfre['director_ids'].values:
    
    c_directores = []
    
    for director in directores :
    

        if director == row:
            c_directores.append(1)  
        else:
            c_directores.append(0)  
    

    datos_directores.append(c_directores)


df_directores = pd.DataFrame(data=datos_directores, columns=list(directores))
dfre3 = pd.concat([dfre, df_directores], axis=1)
dfre["Puntuaciond"]= (dfre3[directores] * usuario_dp).sum(axis=1)

# %%
#generacion de pesos del usuario por actor
dfme['actor_ids'] = dfme['actor_ids'].fillna('')
actores_unicos = set()
for actor in dfme['actor_ids'].values:
    actores = actor.split(", ")
    actores_unicos.update(actores)

actores_unicos = list(actores_unicos)



datos = []

for row in dfme[dfme["Rating"] > 0]["actor_ids"].values:

    actores_peliculas = list()
    
    for cat in actores_unicos:
    
        if cat in row.split(", "):
            actores_peliculas.append(1)
        else:
            actores_peliculas.append(0)

    datos.append(actores_peliculas)


df_actores_peliculas = pd.DataFrame(data = datos, columns = list(actores_unicos))
dfme.reset_index(drop=True, inplace=True)

weighted_genre_matrix = pd.concat([dfme, df_actores_peliculas], axis = 1)
weighted_genre_matrix = (weighted_genre_matrix[actores_unicos].values.T * weighted_genre_matrix['Rating'].values).T
weighted_genre_matrix = pd.DataFrame(weighted_genre_matrix, columns = actores_unicos)

usuario_ac = weighted_genre_matrix.sum()

usuario_ac = usuario_ac / usuario_ac.sum()

usuario_ac
# Out:
# 81643      0.001866
# 826256     0.003109
# 708182     0.001244
# 1403288    0.005597
# 126996     0.003109
#              ...
# 687987     0.000622
# 49379      0.002488
# 343075     0.003109
# 875074     0.001244
# 2038       0.001244
# Length: 464, dtype: float64

# %%
# generar dataframe columnas por cada actor (en los pesos del usuario) y generar puntuacion por actor
datos = []
dfre['actor_ids'] = dfre['actor_ids'].fillna('')
for row in dfre['actor_ids'].values:
    actores_peliculas = list()
    for cat in actores_unicos:
        if cat in row.split(", "):
            actores_peliculas.append(1)
        else:
            actores_peliculas.append(0)
    datos.append(actores_peliculas)

df_actores_peliculas = pd.DataFrame(data=datos, columns=list(actores_unicos))
dfre4 = pd.concat([dfre, df_actores_peliculas], axis=1)
dfre["Puntuacionac"]=(dfre4[actores_unicos] * usuario_ac).sum(axis=1)

# %%
#lemmatizer = WordNetLemmatizer()
#stop_words = set(stopwords.words('english'))

#def preprocess_text(text):
    #if pd.isnull(text):
       # return ""
    #tokens = word_tokenize(str(text).lower())
    #tokens = [lemmatizer.lemmatize(word) for word in tokens if word.isalnum()]
#     tokens = [word for word in tokens if word not in stop_words]
#     return " ".join(tokens)
    
# # Preprocesa las descripciones
# dfre5 = pd.DataFrame()
# dfre5['processed_description'] = dfre['description'].apply(preprocess_text)

# # Vectoriza las descripciones preprocesadas
# vectorizer = TfidfVectorizer()
# tfidf_matrix = vectorizer.fit_transform(dfre5['processed_description'])

# # Calcula la matriz de similitud de coseno
# similarity_matrix = cosine_similarity(tfidf_matrix, tfidf_matrix)

# # Define la función de recomendación
# def get_recommendations(movie_titles, similarity_matrix, df):
#     sim_scores_suma = [0] * len(df)
#     for movie_title in movie_titles:
#         idx = df.index[df['title'] == movie_title].tolist()[0]
#         sim_scores = list(enumerate(similarity_matrix[idx]))
#         for i, score in sim_scores:
#             #if i != idx:  # Omitir la película misma
#              sim_scores_suma[i] += score
    
#     numero_movies = len(movie_titles)
#     sim_scores_media = [score / numero_movies for score in sim_scores_suma]
    

#     for i in range(len(df)):
#         df.at[i, 'Puntuacion_des'] = sim_scores_media[i]
        
#     return df

# %%
# if (dfme['Rating'] == 5).any():
#     peliculas_5 = dfme.loc[dfme['Rating'] == 5, 'title'].tolist()
#     if len(peliculas_5) == 1:
#         movie_title = peliculas_5[0]
#         dfre['Puntuacion_des'] = 0
#         dfre['Puntuacion_des'] = dfre['Puntuacion_des'].astype(float)
#         recommendations = get_recommendations([movie_title], similarity_matrix, dfre)
#     else:
#         dfre['Puntuacion_des'] = 0
#         dfre['Puntuacion_des'] = dfre['Puntuacion_des'].astype(float)
#         recommendations = get_recommendations(peliculas_5, similarity_matrix, dfre)
# else:
#     print("No hay ninguna película con un rating de 5.")

# %%
dfre = dfre[~dfre['title'].isin(dfme['title'])]
dfre = dfre.copy()

# %% [markdown]
# Generacion de recomendaciones

# %%
# se normalizan las puntuaciones y se le da un peso de 65 % a genero 20 % a director, 10 a actores y 5 a descripcion
# en caso de no haya valorado ninguna pelicula con un 5 - son 65 % genero 25 % director y 10 % actores

# %%
def calcular_puntuacion(row):
    if row["type"] == "MOVIE":
        return (
                0.72 * (row['Puntuacionge'] - dfre['Puntuacionge'].min()) / (dfre['Puntuacionge'].max() - dfre['Puntuacionge'].min()) +
                0.12 * row["Puntuaciond"] / dfre["Puntuaciond"].max() +
                0.08 * row["Puntuacionac"] / dfre["Puntuacionac"].max()+
                0.08 *(row['imdb_score'] - dfre['imdb_score'].min()) / (dfre['imdb_score'].max() - dfre['imdb_score'].min())
            )
    else:
         return (
                0.80 * (row['Puntuacionge'] - dfre['Puntuacionge'].min()) / (dfre['Puntuacionge'].max() - dfre['Puntuacionge'].min()) +
                0.10 * row["Puntuacionac"] / dfre["Puntuacionac"].max()+
                0.10 *(row['imdb_score'] - dfre['imdb_score'].min()) / (dfre['imdb_score'].max() - dfre['imdb_score'].min())
            )

dfre["Puntuacion"] = dfre.apply(calcular_puntuacion, axis=1)

# %%
dfrem = dfre[dfre["type"] == "MOVIE"]
dfres = dfre[dfre["type"] == "SHOW"]

# %%
recomendaciones1 = dfrem.sort_values(by='Puntuacion', ascending=False)
recomendaciones2 = dfres.sort_values(by='Puntuacion', ascending=False)

# %%
recomendaciones1.head(12)
# Out:
#               id                                             title   type  \
# 4403    tm142381     The Lord of the Rings: The Return of the King  MOVIE
# 5144    tm158094         The Hobbit: The Battle of the Five Armies  MOVIE
# 5739    tm171483               The Hobbit: The Desolation of Smaug  MOVIE
# 7275    tm221953                        Bāhubali 2: The Conclusion  MOVIE
# 4110    tm137002                           Bāhubali: The Beginning  MOVIE
# 2856   tm1216297                                   King of Thieves  MOVIE
# 6054    tm178788                                         King Kong  MOVIE
# 10221   tm374208            Detective Dee: The Four Heavenly Kings  MOVIE
# 4007    tm134516  Crouching Tiger, Hidden Dragon: Sword of Destiny  MOVIE
# 5476    tm165169                                 Beowulf & Grendel  MOVIE
# 6352      tm1855                                 Avengers: Endgame  MOVIE
# 15754   tm865501                       Black Fox: Age of the Ninja  MOVIE
#
#                                              description  release_year  \
# 4403   Aragorn is revealed as the heir to the ancient...          2003
# 5144   Immediately after the events of The Desolation...          2015
# 5739   The Dwarves, Bilbo and Gandalf have successful...          2014
# 7275   When Mahendra, the son of Bāhubali, learns abo...          2017
# 4110   The young Shivudu is left as a foundling in a ...          2015
# 2856   Driven by the thirst for revenge, an invincibl...          2022
# 6054   In 1933 New York, an overly ambitious movie pr...          2005
# 10221  Dee, the detective serving Chinese empress Wu ...          2018
# 4007   A story of lost love, young love, a legendary ...          2016
# 5476   The blood-soaked tale of a Norse warrior's bat...          2006
# 6352   After the devastating events of Avengers: Infi...          2019
# 15754  A young girl named Miya, who is chased because...          2019
#
#       age_certification  runtime                                   genres  \
# 4403              PG-13      201           ['fantasy', 'action', 'drama']
# 5144              PG-13      144                    ['fantasy', 'action']
# 5739              PG-13      161                    ['fantasy', 'action']
# 7275                NaN      167           ['fantasy', 'action', 'drama']
# 4110                NaN      158           ['action', 'drama', 'fantasy']
# 2856                NaN      108           ['action', 'drama', 'fantasy']
# 6054              PG-13      187           ['drama', 'action', 'romance']
# 10221               NaN      132           ['action', 'drama', 'fantasy']
# 4007              PG-13       96           ['drama', 'fantasy', 'action']
# 5476                  R      103           ['drama', 'fantasy', 'action']
# 6352              PG-13      181  ['scifi', 'action', 'drama', 'fantasy']
# 15754               NaN       92           ['fantasy', 'action', 'drama']
#
#                  production_countries  seasons  ... tmdb_score  \
# 4403                     ['NZ', 'US']      NaN  ...      8.474
# 5144                     ['US', 'NZ']      NaN  ...      7.310
# 5739                     ['US', 'NZ']      NaN  ...      7.571
# 7275                           ['IN']      NaN  ...      7.399
# 4110                           ['IN']      NaN  ...      7.572
# 2856                               []      NaN  ...        NaN
# 6054               ['DE', 'NZ', 'US']      NaN  ...      6.858
# 10221                    ['CN', 'HK']      NaN  ...      6.303
# 4007                           ['CN']      NaN  ...      6.110
# 5476   ['IS', 'GB', 'US', 'AU', 'CA']      NaN  ...      5.698
# 6352                           ['US']      NaN  ...      8.268
# 15754                          ['JP']      NaN  ...      8.200
#
#                                                   actors  \
# 4403   Elijah Wood, Sean Astin, Ian McKellen, Billy B...
# 5144   Ian McKellen, Martin Freeman, Richard Armitage...
# 5739   Ian McKellen, Martin Freeman, Richard Armitage...
# 7275   Prabhas, Rana Daggubati, Sathyaraj, Anushka Sh...
# 4110   Prabhas, Rana Daggubati, Tamannaah Bhatia, Anu...
# 2856                                                 NaN
# 6054   Naomi Watts, Jack Black, Adrien Brody, Thomas ...
# 10221  Mark Chao, William Feng, Carina Lau, Lin Gengx...
# 4007   Michelle Yeoh, Donnie Yen, Jason Scott Lee, Na...
# 5476   Gerard Butler, Spencer Wilding, Stellan Skarsg...
# 6352   Robert Downey Jr., Chris Evans, Mark Ruffalo, ...
# 15754  Chihiro Yamamoto, Sakurako Okubo, Hideo Ishigu...
#
#                                                actor_ids  \
# 4403   2845, 2857, 2804, 2855, 2846, 1858, 2856, 3260...
# 5144   2804, 7181, 76404, 2848, 49991, 2694, 20047, 1...
# 5739   2804, 7181, 76404, 1396, 2848, 49991, 20047, 2...
# 7275   45431, 45432, 45437, 45433, 45436, 45435, 6725...
# 4110   45431, 45432, 45434, 45433, 45435, 45436, 4543...
# 2856
# 6054   1907, 4677, 4612, 1857, 9313, 5360, 1858, 4075...
# 10221  36788, 36789, 36791, 36575, 200180, 60416, 296...
# 4007   5845, 6663, 6664, 6666, 6665, 6667, 6668, 6669...
# 5476   6888, 9046, 1856, 56817, 56818, 56819, 2149, 5...
# 6352   1842, 1843, 1844, 1736, 1678, 1847, 1854, 1112...
# 15754  282155, 628826, 164717, 184966, 249441, 231231...
#
#                       directors  director_ids      platform Puntuacionge  \
# 4403              Peter Jackson          1283  HBO, Netflix     0.543689
# 5144              Peter Jackson          1283           HBO     0.378641
# 5739              Peter Jackson          1283           HBO     0.378641
# 7275            S. S. Rajamouli         45443       Netflix     0.543689
# 4110            S. S. Rajamouli         45443       Netflix     0.543689
# 2856                        NaN           NaN        Amazon     0.543689
# 6054              Peter Jackson          1283       Netflix     0.322330
# 10221                 Tsui Hark         36580        Amazon     0.543689
# 4007              Yuen Woo-ping          6676       Netflix     0.543689
# 5476          Sturla Gunnarsson         56827        Amazon     0.543689
# 6352   Joe Russo, Anthony Russo  28806, 28805        Disney     0.494175
# 15754           Koichi Sakamoto         58525        Amazon     0.543689
#
#       Puntuaciond Puntuacionac Puntuacion
# 4403         0.54     0.224502   0.991818
# 5144         0.54     0.061567   0.816999
# 5739         0.54     0.049129   0.816203
# 7275         0.00     0.000000   0.784545
# 4110         0.00     0.000000   0.782727
# 2856         0.00     0.000000   0.775455
# 6054         0.54     0.036692   0.771444
# 10221        0.00     0.000000   0.767273
# 4007         0.00     0.002488   0.766341
# 5476         0.00     0.002488   0.763614
# 6352         0.00     0.005597   0.757694
# 15754        0.00     0.000000   0.754545
#
# [12 rows x 24 columns]

# %%
recomendaciones2.head(12)
# Out:
#              id                                      title  type  \
# 22954   ts89210                                Warrior Nun  SHOW
# 22687   ts84392                            The Mandalorian  SHOW
# 22797   ts86474                                       Loki  SHOW
# 19273  ts237713                                Sweet Tooth  SHOW
# 22836   ts87242                            Shadow and Bone  SHOW
# 21203  ts365037        The Bastard Son & the Devil Himself  SHOW
# 20201  ts296563                        Who Rules The World  SHOW
# 21975   ts57325                          The Wheel of Time  SHOW
# 20709  ts325752  The Lord of the Rings: The Rings of Power  SHOW
# 19814  ts271888                        Fate: The Winx Saga  SHOW
# 19354  ts246073                           Tribes of Europa  SHOW
# 20050  ts287559                           Jupiter's Legacy  SHOW
#
#                                              description  release_year  \
# 22954  After waking up in a morgue, an orphaned teen ...          2020
# 22687  After the fall of the Galactic Empire, lawless...          2019
# 22797  After stealing the Tesseract during the events...          2021
# 19273  On a perilous adventure across a post-apocalyp...          2021
# 22836  In a world cleaved in two by a massive barrier...          2021
# 21203  Caught between two warring clans, the son of a...          2022
# 20201  A legendary wuxia romance that focuses on the ...          2022
# 21975  Follow Moiraine, a member of the shadowy and i...          2021
# 20709  Epic drama set thousands of years before the e...          2022
# 19814  The coming-of-age journey of five fairies atte...          2021
# 19354  2074. In the wake of a mysterious global disas...          2021
# 20050  As the world's first generation of superheroes...          2021
#
#       age_certification  runtime                                     genres  \
# 22954             TV-MA       43             ['action', 'drama', 'fantasy']
# 22687             TV-14       40    ['scifi', 'action', 'drama', 'fantasy']
# 22797             TV-14       48    ['drama', 'scifi', 'fantasy', 'action']
# 19273             TV-14       46    ['drama', 'scifi', 'fantasy', 'action']
# 22836             TV-14       56    ['scifi', 'drama', 'fantasy', 'action']
# 21203             TV-MA       49    ['scifi', 'drama', 'fantasy', 'action']
# 20201             TV-PG       46  ['drama', 'action', 'fantasy', 'romance']
# 21975             TV-MA       59    ['scifi', 'drama', 'fantasy', 'action']
# 20709             TV-14       70    ['fantasy', 'action', 'drama', 'scifi']
# 19814               NaN       51    ['scifi', 'drama', 'fantasy', 'action']
# 19354             TV-MA       47    ['scifi', 'drama', 'fantasy', 'action']
# 20050             TV-MA       45    ['scifi', 'drama', 'fantasy', 'action']
#
#       production_countries  seasons  ... tmdb_score  \
# 22954               ['US']      2.0  ...      8.134
# 22687               ['US']      3.0  ...      8.478
# 22797               ['US']      1.0  ...      8.170
# 19273               ['US']      2.0  ...      7.971
# 22836               ['US']      2.0  ...      8.100
# 21203               ['GB']      1.0  ...      7.700
# 20201               ['CN']      1.0  ...      7.000
# 21975               ['US']      1.0  ...      7.766
# 20709               ['US']      1.0  ...      7.491
# 19814               ['GB']      2.0  ...      8.283
# 19354               ['DE']      1.0  ...      7.076
# 20050               ['US']      1.0  ...      7.100
#
#                                                   actors  \
# 22954  Alba Baptista, Tristán Ulloa, Kristina Tonteri...
# 22687                       Pedro Pascal, Katee Sackhoff
# 22797  Tom Hiddleston, Owen Wilson, Sophia Di Martino...
# 19273  Christian Convery, Nonso Anozie, Adeel Akhtar,...
# 22836  Jessie Mei Li, Archie Renaux, Freddy Carter, A...
# 21203  Jay Lycurgo, Nadia Parkes, Paul Ready, Isobel ...
# 20201  Yang Yang, Zhao Lusi, Xuan Lu, Lai Yi, Liu Rui...
# 21975  Rosamund Pike, Daniel Henney, Zoe Robins, Barn...
# 20709  Morfydd Clark, Robert Aramayo, Charlie Vickers...
# 19814  Abigail Cowen, Hannah van der Westhuysen, Prec...
# 19354  Emilio Sakraya, Henriette Confurius, David Ali...
# 20050  Josh Duhamel, Ben Daniels, Leslie Bibb, Andrew...
#
#                                                actor_ids  \
# 22954  263945, 15911, 1072959, 757594, 124252, 18152,...
# 22687                                       32436, 27489
# 22797            2134, 4621, 260073, 36136, 14023, 20372
# 19273   606757, 13196, 13572, 28926, 16301, 130094, 6061
# 22836    1219860, 989489, 698851, 1080629, 1160365, 7111
# 21203         1390893, 1042587, 114627, 2527516, 1351541
# 20201  126992, 898052, 1130646, 835611, 709739, 33418...
# 21975  9044, 24694, 606259, 226803, 121886, 737756, 8...
# 20709  62006, 227043, 1112685, 12491, 36942, 1309559,...
# 19814  860273, 331808, 1156312, 239999, 1275303, 1052...
# 19354  73071, 71704, 1479230, 589251, 590832, 21660, ...
# 20050  16895, 13160, 11953, 975802, 19324, 897349, 15186
#
#                            directors   director_ids platform Puntuacionge  \
# 22954                            NaN            NaN  Netflix     0.543689
# 22687                            NaN            NaN   Disney     0.494175
# 22797                            NaN            NaN   Disney     0.494175
# 19273                            NaN            NaN  Netflix     0.494175
# 22836                            NaN            NaN  Netflix     0.494175
# 21203                            NaN            NaN  Netflix     0.494175
# 20201                        Yin Tao         649537  Netflix     0.477670
# 21975                            NaN            NaN   Amazon     0.494175
# 20709                            NaN            NaN   Amazon     0.494175
# 19814                            NaN            NaN  Netflix     0.494175
# 19354  Philip Koch, Florian Baxmeyer  30395, 140611  Netflix     0.494175
# 20050                            NaN            NaN  Netflix     0.494175
#
#       Puntuaciond Puntuacionac Puntuacion
# 22954         0.0     0.000000   0.867045
# 22687         0.0     0.000000   0.852293
# 22797         0.0     0.000622   0.846888
# 19273         0.0     0.000000   0.842065
# 22836         0.0     0.000000   0.839793
# 21203         0.0     0.000000   0.838656
# 20201         0.0     0.000000   0.836390
# 21975         0.0     0.000000   0.835247
# 20709         0.0     0.000000   0.831838
# 19814         0.0     0.000000   0.830702
# 19354         0.0     0.000000   0.829565
# 20050         0.0     0.000000   0.829565
#
# [12 rows x 24 columns]
